# %%
import urllib.request
from time import sleep
import mysql.connector

class Comms:
    def __init__(self, id, location):
        self.__dbname = "sql6497641"
        self.__dbuser = "sql6497641"
        self.__dbpass = "9c7ymcwsIl"
        self.__dbhost = "sql6.freemysqlhosting.net"
        self.__tbname = "emergency"

        self.__id = id  # primary key id
        self.__location = location

        # connects the python to a remote database
        self.__connect(self.__dbhost, self.__dbuser, self.__dbpass, self.__dbname)

        # introduce self to database
        self.__introduce()

    def __del__(self):
        self.close_conn()

    def close_conn(self):
        self.cursor.close()
        self.mydb.close()

    def __introduce(self):
        # introduce self to database
        try:
            query = f"""INSERT INTO {self.__tbname} (id, location, sos) VALUES ('{self.__id}', '{self.__location}', false) ON DUPLICATE KEY UPDATE location='{self.__location}';"""
            self.cursor.execute(query)
            self.mydb.commit()

        except mysql.connector.Error as err:
            print("\nError: " + err.msg)

    def __connect(self, dbhost, dbuser, dbpass, dbname):
        try:
            self.mydb = mysql.connector.connect(
                host=dbhost,
                user=dbuser,
                password=dbpass,
                database=dbname,
            )

            self.cursor = self.mydb.cursor(buffered=True)

        except mysql.connector.Error as err:
            print("\nError: " + err.msg)

    def __reconnect(self):
        # close connections
        self.close_conn()

        # reconnect to the database
        self.__connect(self.__dbhost, self.__dbuser, self.__dbpass, self.__dbname)

    def send_sos(self):
        # reconnect
        self.__reconnect()

        # send SOS to the base
        query = f"""UPDATE {self.__tbname} SET sos=true WHERE id='{self.__id}';"""
        self.cursor.execute(query)
        self.mydb.commit()
        print(f"SOS at {self.__location} has been sent.")

    def is_clear(self):
        # reconnect
        self.__reconnect()

        # check if SOS has responded
        query = f"""SELECT * FROM {self.__tbname} WHERE id='{self.__id}';"""
        self.cursor.execute(query)
        row = self.cursor.fetchone()

        if row[3] == 0:
            # Node is clear
            return True
        else:
            # Node is not clear
            return False


#nodemcu

url = "http://192.168.5.214"  

def get_data():

    n = urllib.request.urlopen(url).read() # get the raw html data in bytes (sends request and warn our esp8266)
    n = n.decode("utf-8") # convert raw html bytes format to string :3
    
    return n
    
info = Comms(1710351, 'PASIG')  

while True:
    
    node = get_data()
    
    if node == '1':    
        info.send_sos() 
    sleep(3)
# Out:
# True
# True
# SOS at PASIG has been sent.
# False
# False
# False
# True
# True
# SOS at PASIG has been sent.
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20508\642911945.py in <module>
#     100 while True:
#     101
# --> 102     node = get_data()
#     103
#     104     if node == '1':
#
# ~\AppData\Local\Temp\ipykernel_20508\642911945.py in get_data()
#      91 def get_data():
#      92
# ---> 93     n = urllib.request.urlopen(url).read() # get the raw html data in bytes (sends request and warn our esp8266)
#      94     n = n.decode("utf-8") # convert raw html bytes format to string :3
#      95
#
# C:\Anaconda\envs\cpe101\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\Anaconda\envs\cpe101\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\Anaconda\envs\cpe101\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# C:\Anaconda\envs\cpe101\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\Anaconda\envs\cpe101\lib\urllib\request.py in http_open(self, req)
#    1376
#    1377     def http_open(self, req):
# -> 1378         return self.do_open(http.client.HTTPConnection, req)
#    1379
#    1380     http_request = AbstractHTTPHandler.do_request_
#
# C:\Anaconda\envs\cpe101\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
# -> 1353             r = h.getresponse()
#    1354         except:
#    1355             h.close()
#
# C:\Anaconda\envs\cpe101\lib\http\client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# C:\Anaconda\envs\cpe101\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# C:\Anaconda\envs\cpe101\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# C:\Anaconda\envs\cpe101\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
